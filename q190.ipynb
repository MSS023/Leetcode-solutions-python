# %%
from typing import *

# %%
class Solution:
    def reverseBits(self, n: int) -> int:
        bStr = f"{n:b}".rjust(32,"0")

        return int(bStr[::-1],2)

# %%
print(Solution().reverseBits(43261596))

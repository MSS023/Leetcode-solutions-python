# %%
import math

# %%
from math import log2

class Solution:
    def concatenatedBinary(self, n: int) -> int:
        res = 0
        MOD = 7 + 10**9
        for i in range(1,n+1):
            res = res << int(log2(i)+1)
            res += i
            res %= MOD
        return res

# %%
class Solution:
    def concatenatedBinary(self, n: int) -> int:
        res = ""
        MOD = 7 + 10**9
        for i in range(1,n+1):
            res += "{:0b}".format(i)
        return int(res,2)%MOD

# %%
class Solution:
    def concatenatedBinary(self, n: int) -> int:
        MOD = 7 + 10**9
        result = 0
        for num in range(1,n+1):
            places = int(math.log2(num)+1)
            result = result << places
            result %= MOD
            result += num
            result %= MOD
        return result

# %%
1 << int(log2(6)+1)
# Out:
# 8

# %%
Solution().concatenatedBinary(3)
# Out:
# 27
